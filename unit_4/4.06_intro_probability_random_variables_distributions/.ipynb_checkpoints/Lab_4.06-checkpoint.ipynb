# %% [markdown]
# # Lab | Random variable distributions
#
# Refer to the files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv dataset.
#
# ### Instructions
#     · Get the numerical variables from our dataset.
#     · Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
#     · Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")

# %%
numericals = data.select_dtypes(include=np.number)
numericals
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
for c in numericals:
    plt.figure(figsize=(10,5))
    plt.hist(data[c], bins = 100)
    plt.title(c)
    plt.show();

# %%
def log_transfom_clean1(x):
    x = np.log(x)
    if np.isfinite(x): #para protegernos del hecho de que log(0) = infinito
        return x
    else:
        return 0
    
numerical_list = numericals.columns.tolist()
print(numerical_list)

for i in numerical_list:
    numericals[i+'_log'] = list(map(log_transfom_clean1, numerical[i]))
    numericals = numericals.drop([i], axis=1)

numericals
# Out:
# ['Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Number of Open Complaints', 'Number of Policies', 'Total Claim Amount']
# C:\Users\EB885UN\AppData\Local\Temp\ipykernel_24144\920661474.py:2: RuntimeWarning: divide by zero encountered in log
#   x = np.log(x)
# C:\Users\EB885UN\AppData\Local\Temp\ipykernel_24144\920661474.py:2: RuntimeWarning: divide by zero encountered in log
#   x = np.log(x)
# C:\Users\EB885UN\AppData\Local\Temp\ipykernel_24144\920661474.py:2: RuntimeWarning: divide by zero encountered in log
#   x = np.log(x)
# C:\Users\EB885UN\AppData\Local\Temp\ipykernel_24144\920661474.py:2: RuntimeWarning: divide by zero encountered in log
#   x = np.log(x)
#       Customer Lifetime Value_log  Income_log  Monthly Premium Auto_log  \
# 0                        7.924260   10.937988                  4.234107
# 1                        8.850738    0.000000                  4.543295
# ...

# %%
for c in numericals:
    plt.figure(figsize=(10,5))
    plt.hist(numericals[c], bins = 100)
    plt.title(c)
    plt.show();

# %%
#He aplicado la transofrmación logarítmica a todas las variables numéricas pero realmente sólo
#le vería sentido a hacerlo para "customer lifetime value" y (si no fuera la variable objetivo)
#a "total claim amount"
